# %%
import seaborn as sns
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('INFORM Risk 2024.csv')

# %%
data.head()
# Out:
#     Unnamed: 0 Unnamed: 1   Unnamed: 2            Unnamed: 3 Unnamed: 4  \
# 0      COUNTRY       ISO3  INFORM RISK            RISK CLASS       Rank
# 1        (a-z)      (a-z)       (0-10)  (Very Low-Very High)    (1-191)
# 2  Afghanistan        AFG          8.1             Very High          4
# 3      Albania        ALB          3.1                   Low        104
# 4      Algeria        DZA          3.6                Medium         81
#
#                 Unnamed: 5         Unnamed: 6 Unnamed: 7  Unnamed: 8  \
# 0  Lack of Reliability (*)  HAZARD & EXPOSURE    Natural  Earthquake
# 1                   (0-10)             (0-10)     (0-10)      (0-10)
# 2                   -187.4                8.7        5.7         8.7
# 3                   -156.3                3.4        5.7         8.3
# 4                   -144.2                3.8        3.2         7.9
#
#     Unnamed: 9  ... Unnamed: 32 Unnamed: 33     Unnamed: 34    Unnamed: 35  \
# 0  River Flood  ...         DRR  Governance  Infrastructure  Communication
# 1       (0-10)  ...      (0-10)      (0-10)          (0-10)         (0-10)
# 2          7.3  ...         6.3         8.0             7.0            6.3
# 3          4.6  ...           x         5.7             2.3            2.0
# 4          3.6  ...         3.5         6.5             3.7            2.9
#
#                Unnamed: 36            Unnamed: 37  \
# 0  Physical infrastructure  Access to health care
# 1                   (0-10)                 (0-10)
# 2                      6.5                    8.1
# 3                      1.4                    3.4
# 4                      4.1                    4.1
#
#                     Unnamed: 38              Unnamed: 39       Unnamed: 40  \
# 0  Number of Missing Indicators  % of Missing Indicators  Countries in HVC
# 1                        (0-50)                 (0-100%)          (Yes/No)
# 2                             4                       8%               YES
# 3                             6                      12%               NaN
# 4                             0                       0%               NaN
#
#                        Unnamed: 41
# 0  Recentness data (average years)
# 1                               ()
# 2                           -28.31
# 3                           -29.61
# 4                           -27.04
#
# [5 rows x 42 columns]

# %%
header = data.iloc[0]
data = data[2:]
data.columns = header

# %%
data.head()
# Out:
# 0              COUNTRY ISO3 INFORM RISK RISK CLASS Rank  \
# 2          Afghanistan  AFG         8.1  Very High    4
# 3              Albania  ALB         3.1        Low  104
# 4              Algeria  DZA         3.6     Medium   81
# 5               Angola  AGO         5.2       High   32
# 6  Antigua and Barbuda  ATG         2.3        Low  151
#
# 0 Lack of Reliability (*) HAZARD & EXPOSURE Natural Earthquake River Flood  \
# 2                  -187.4               8.7     5.7        8.7         7.3
# 3                  -156.3               3.4     5.7        8.3         4.6
# 4                  -144.2               3.8     3.2        7.9         3.6
# 5                  -142.3               4.2     2.9        0.1         3.9
# 6                  -183.8               2.0     3.7        5.1         0.0
#
# 0  ...  DRR Governance Infrastructure Communication Physical infrastructure  \
# 2  ...  6.3        8.0            7.0           6.3                     6.5
# 3  ...    x        5.7            2.3           2.0                     1.4
# 4  ...  3.5        6.5            3.7           2.9                     4.1
# 5  ...  5.2        6.9            7.3           6.3                     7.9
# 6  ...  5.4        5.3            1.3           0.2                     0.7
#
# 0 Access to health care Number of Missing Indicators % of Missing Indicators  \
# 2                   8.1                            4                      8%
# 3                   3.4                            6                     12%
# 4                   4.1                            0                      0%
# 5                   7.8                            0                      0%
# 6                   3.1                           18                     35%
#
# 0 Countries in HVC Recentness data (average years)
# 2              YES                          -28.31
# 3              NaN                          -29.61
# 4              NaN                          -27.04
# 5              NaN                          -26.69
# 6              NaN                          -35.21
#
# [5 rows x 42 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 2 to 192
# Data columns (total 42 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   COUNTRY                                    191 non-null    object
#  1   ISO3                                       191 non-null    object
#  2   INFORM RISK                                191 non-null    object
#  3   RISK CLASS                                 191 non-null    object
#  4   Rank                                       191 non-null    object
#  5   Lack of Reliability (*)                    191 non-null    object
#  6   HAZARD & EXPOSURE                          191 non-null    object
#  7   Natural                                    191 non-null    object
#  8   Earthquake                                 191 non-null    object
#  9   River Flood                                191 non-null    object
#  10  Tsunami                                    191 non-null    object
#  11  Tropical Cyclone                           191 non-null    object
#  12  Coastal flood                              191 non-null    object
#  13  Drought                                    191 non-null    object
#  14  Epidemic                                   191 non-null    object
#  15  Human                                      191 non-null    object
#  16  Projected Conflict Risk                    191 non-null    object
#  17  Current Highly Violent Conflict Intensity  191 non-null    object
#  18  VULNERABILITY                              191 non-null    object
#  19  Socio-Economic Vulnerability               191 non-null    object
#  20  Development & Deprivation                  191 non-null    object
#  21  Inequality                                 191 non-null    object
#  22  Economic Dependency                        191 non-null    object
#  23  Vulnerable Groups                          191 non-null    object
#  24  Uprooted people                            191 non-null    object
#  25  Health Conditions                          191 non-null    object
#  26  Children U5                                191 non-null    object
#  27  Recent Shocks                              191 non-null    object
#  28  Food Security                              191 non-null    object
#  29  Other Vulnerable Groups                    191 non-null    object
#  30  LACK OF COPING CAPACITY                    191 non-null    object
#  31  Institutional                              191 non-null    object
#  32  DRR                                        191 non-null    object
#  33  Governance                                 191 non-null    object
#  34  Infrastructure                             191 non-null    object
#  35  Communication                              191 non-null    object
#  36  Physical infrastructure                    191 non-null    object
#  37  Access to health care                      191 non-null    object
#  38  Number of Missing Indicators               191 non-null    object
#  39  % of Missing Indicators                    191 non-null    object
#  40  Countries in HVC                           28 non-null     object
#  41  Recentness data (average years)            191 non-null    object
# dtypes: object(42)
# memory usage: 62.8+ KB

# %%
for column in data.columns:
    print(data[column][2], type(data[column][2]))
# Out:
# Afghanistan <class 'str'>
# AFG <class 'str'>
# 8.1 <class 'str'>
# Very High <class 'str'>
# 4 <class 'str'>
# -187.4 <class 'str'>
# 8.7 <class 'str'>
# 5.7 <class 'str'>
# 8.7 <class 'str'>
# 7.3 <class 'str'>
# 0.0 <class 'str'>
# 0.0 <class 'str'>
# 0.0 <class 'str'>
# 8.6 <class 'str'>
# 6.9 <class 'str'>
# 10.0 <class 'str'>
# 10.0 <class 'str'>
# 10.0 <class 'str'>
# 8.5 <class 'str'>
# 8.3 <class 'str'>
# 8.7 <class 'str'>
# 9.0 <class 'str'>
# 6.9 <class 'str'>
# 8.6 <class 'str'>
# 10.0 <class 'str'>
# 2.0 <class 'str'>
# 4.3 <class 'str'>
# 7.3 <class 'str'>
# 7.1 <class 'str'>
# 5.6 <class 'str'>
# 7.1 <class 'str'>
# 7.2 <class 'str'>
# 6.3 <class 'str'>
# 8.0 <class 'str'>
# 7.0 <class 'str'>
# 6.3 <class 'str'>
# 6.5 <class 'str'>
# 8.1 <class 'str'>
# 4 <class 'str'>
# 8% <class 'str'>
# YES <class 'str'>
# -28.31 <class 'str'>

# %%
data.replace('x', 0, inplace=True)

# %%
for col in data.columns[4:39]:
    data[col].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 2
#       1 for col in data.columns[4:39]:
# ----> 2     data[col].astype(float)
#
# File C:\Users\eleanor\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File C:\Users\eleanor\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File C:\Users\eleanor\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File C:\Users\eleanor\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File C:\Users\eleanor\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File C:\Users\eleanor\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\Users\eleanor\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '#ERROR!'

# %%
df = data.copy()
df = df[df.columns[4:39]]
print(df)
#for col in df:
    #pd.to_numeric(df[col])

# %%
corr = data.corr(numeric_only=True)
corr
#sns.heatmap(data=corr,vmin=-1,vmax=1,annot=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
